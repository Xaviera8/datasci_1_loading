# %% [markdown]
# <a href="https://colab.research.google.com/github/Xaviera8/datasci_1_loading/blob/main/HHA507CLASS1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Week 1: Introduction to Jupyter Notebooks (Google Colab) and Data Acquisition
# Objective:
#
# Familiarize yourself with Jupyter Notebook (Google Colab), practice data acquisition techniques, and begin using GitHub for assignment submissions.
# Instructions:
# 1. Setting Up Google Colab:
#
#     Create a new notebook in Google Colab.
#     Familiarize yourself with the Colab interface: exploring the menu options, inserting code and text cells, and using the file browser.
#
# 2. Data Acquisition:
#
#     Find and download at least 2-3 different CSV datasets (less than 10MB each) that do not contain any PHI/PII.
#     Similarly, find and download 3 XLSX files and 3 JSON files with the same criteria.
#     Use pandas to load each of these datasets into separate data frames in your Colab notebook.
#     Display the first 10 rows of each dataset in separate code cells.
#
# 3. Markdown Practice:
#
#     Add a markdown cell and list the features (columns) of each dataset.
#     For each feature, give a brief description of its content/purpose.
#
# 3. Submission:
#
#     Create a new GitHub repository named datasci_1_loading in your GitHub account.
#     Organize your GitHub repository with the following:
#         Within your repository, create a folder named "data" to store your acquired datasets.
#         Save your Colab notebook to your GitHub repository.
#         Submit the link to your GitHub repository.

# %% [markdown]
# #Import Pandas

# %%
import pandas as pd

# %% [markdown]
# #Insert Files

# %%
csvs = ['nba_draft_combine_all_years.csv',
        'players.csv']

json_files = ['shoe prices.json',
              'GCB2022v27_percapita_flat_metadata.json']

xlsx_files = ['winter.xlsx',
              'sampledatafoodinfo.xlsx',
              'sampledatafoodsales.xlsx',
              'sampledata.xlsx']

# %% [markdown]
# #Read CSVs

# %%
df1 = pd.read_csv(csvs[0], nrows=10)
df1
# Out:
#    Unnamed: 0             Player  Year  Draft pick  Height (No Shoes)  \
# 0           0      Blake Griffin  2009           1              80.50
# 1           1  Terrence Williams  2009          11              77.00
# 2           2   Gerald Henderson  2009          12              76.00
# 3           3   Tyler Hansbrough  2009          13              80.25
# 4           4         Earl Clark  2009          14              80.50
# 5           5        Austin Daye  2009          15              81.75
# 6           6      James Johnson  2009          16              79.00
# 7           7       Jrue Holiday  2009          17              75.25
# 8           8          Ty Lawson  2009          18              71.25
# 9           9        Jeff Teague  2009          19              72.25
#
#    Height (With Shoes)  Wingspan  Standing reach  Vertical (Max)  \
# 0                82.00     83.25           105.0            35.5
# 1                78.25     81.00           103.5            37.0
# 2                77.00     82.25           102.5            35.0
# 3                81.50     83.50           106.0            34.0
# 4                82.25     86.50           109.5            33.0
# 5                82.75     86.75           110.0            28.0
# 6                79.75     84.75           105.5            35.0
# 7                76.25     79.00           100.5            34.0
# 8                72.50     72.75            94.5            36.5
# 9                73.50     79.50            98.5            36.5
#
#    Vertical (Max Reach)  Vertical (No Step)  Vertical (No Step Reach)  Weight  \
# 0                 140.5                32.0                     137.0   248.0
# 1                 140.5                30.5                     134.0   213.0
# 2                 137.5                31.5                     134.0   215.0
# 3                 140.0                27.5                     133.5   234.0
# 4                 142.5                28.5                     138.0   228.0
# 5                 138.0                25.0                     135.0   192.0
# 6                 140.5                30.5                     136.0   257.0
# 7                 134.5                28.5                     129.0   199.0
# 8                 131.0                29.0                     123.5   197.0
# 9                 135.0                30.5                     129.0   175.0
#
#    Body Fat  Hand (Length)  Hand (Width)  Bench  Agility  Sprint
# 0       8.2            NaN           NaN   22.0    10.95    3.28
# 1       5.1            NaN           NaN    9.0    11.15    3.18
# 2       4.4            NaN           NaN    8.0    11.17    3.14
# 3       8.5            NaN           NaN   18.0    11.12    3.27
# 4       5.2            NaN           NaN    5.0    11.17    3.35
# 5       5.5            NaN           NaN    NaN    12.11    3.55
# 6      12.0            NaN           NaN   18.0    11.21    3.23
# 7       6.3            NaN           NaN    6.0    10.64    3.21
# 8       6.6            NaN           NaN   14.0    10.98    3.12
# 9       4.5            NaN           NaN   13.0    11.05    3.18

# %%
df2 = pd.read_csv(csvs[1], nrows=10)
df2
# Out:
#          _id          birthDate                birthPlace  career_AST  \
# 0  abdelal01      June 24, 1968              Cairo, Egypt         0.3
# 1  abdulza01      April 7, 1946        Brooklyn, New York         1.2
# 2  abdulka01     April 16, 1947        New York, New York         3.6
# 3  abdulma02      March 9, 1969     Gulfport, Mississippi         3.5
# 4  abdulta01   November 3, 1974    Maisons Alfort, France         1.1
# 5  abdursh01  December 11, 1976         Marietta, Georgia         2.5
# 6  abernto01        May 6, 1954       South Bend, Indiana         1.2
# 7   ablefo01      July 27, 1932                       NaN         1.0
# 8  abramjo01   February 9, 1919        Etna, Pennsylvania         0.7
# 9  abrinal01     August 1, 1993  Palma de Mallorca, Spain         0.5
#
#    career_FG%  career_FG3% career_FT%  career_G career_PER  career_PTS  ...  \
# 0        50.2          0.0       70.1       256       13.0         5.7  ...
# 1        42.8          NaN       72.8       505       15.1         9.0  ...
# 2        55.9          5.6       72.1      1560       24.6        24.6  ...
# 3        44.2         35.4       90.5       586       15.4        14.6  ...
# 4        41.7         23.7       70.3       236       11.4         7.8  ...
# 5        47.2         29.7       81.0       830       19.0        18.1  ...
# 6        49.2          0.0       74.7       319       12.9         5.6  ...
# 7         0.0          NaN          -         1      -41.1         0.0  ...
# 8        23.7          NaN       68.6        56          -         9.5  ...
# 9        38.7         36.8       88.0       174        8.8         5.3  ...
#
#      draft_pick    draft_round              draft_team draft_year height  \
# 0  25th overall      1st round  Portland Trail Blazers     1990.0   6-10
# 1   5th overall      1st round       Cincinnati Royals     1968.0    6-9
# 2   1st overall      1st round         Milwaukee Bucks     1969.0    7-2
# 3   3rd overall      1st round          Denver Nuggets     1990.0    6-1
# 4  11th overall      1st round        Sacramento Kings     1997.0    6-6
# 5   3rd overall      1st round     Vancouver Grizzlies     1996.0    6-9
# 6  43rd overall      3rd round      Los Angeles Lakers     1976.0    6-7
# 7           NaN  1956 NBA Draf      Syracuse Nationals        NaN    6-3
# 8           NaN            NaN                     NaN        NaN    6-3
# 9  32nd overall      2nd round   Oklahoma City Thunder     2013.0    6-6
#
#                                 highSchool                 name  \
# 0     Bloomfield in Bloomfield, New Jersey       Alaa Abdelnaby
# 1           John Jay in Brooklyn, New York      Zaid Abdul-Aziz
# 2     Power Memorial in New York, New York  Kareem Abdul-Jabbar
# 3        Gulfport in Gulfport, Mississippi   Mahmoud Abdul-Rauf
# 4  Lycee Aristide Briand in Evreux, France    Tariq Abdul-Wahad
# 5             Wheeler in Marietta, Georgia  Shareef Abdur-Rahim
# 6      Saint Joseph in South Bend, Indiana        Tom Abernethy
# 7         Fairdale in Louisville, Kentucky          Forest Able
# 8               Etna in Etna, Pennsylvania       John Abramovic
# 9                                      NaN         Alex Abrines
#
#                                      position shoots weight
# 0                               Power Forward  Right  240lb
# 1                    Power Forward and Center  Right  235lb
# 2                                      Center  Right  225lb
# 3                                 Point Guard  Right  162lb
# 4                              Shooting Guard  Right  223lb
# 5  Center and Small Forward and Power Forward  Right  225lb
# 6             Small Forward and Power Forward  Right  220lb
# 7                                       Guard  Right  180lb
# 8                                     Forward  Right  195lb
# 9                              Shooting Guard  Right  200lb
#
# [10 rows x 24 columns]

# %% [markdown]
# #Read XLSX files

# %%
pd.read_excel('winter.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-086b8e36d62c> in <cell line: 1>()
# ----> 1 pd.read_excel('winter.xlsx')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480     if not isinstance(io, ExcelFile):
#     481         should_close = True
# --> 482         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483     elif engine and engine != io.engine:
#     484         raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1650                 ext = "xls"
#    1651             else:
# -> 1652                 ext = inspect_excel_format(
#    1653                     content_or_path=path_or_buffer, storage_options=storage_options
#    1654                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1523         content_or_path = BytesIO(content_or_path)
#    1524
# -> 1525     with get_handle(
#    1526         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1527     ) as handle:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     863         else:
#     864             # Binary mode
# --> 865             handle = open(handle, ioargs.mode)
#     866         handles.append(handle)
#     867
#
# FileNotFoundError: [Errno 2] No such file or directory: 'winter.xlsx'

# %%
pd.read_excel(xlsx_files[1], nrows=10)
# Out:
#         ID       Date Region         City  Category         Product  Qty  \
# 0  ID07351 2022-01-01   East       Boston      Bars          Carrot   33
# 1  ID07352 2022-01-04   East       Boston  Crackers     Whole Wheat   87
# 2  ID07353 2022-01-07   West  Los Angeles   Cookies  Chocolate Chip   58
# 3  ID07354 2022-01-10   East     New York   Cookies  Chocolate Chip   82
# 4  ID07355 2022-01-13   East       Boston   Cookies       Arrowroot   38
# 5  ID07356 2022-01-16   East       Boston      Bars          Carrot   54
# 6  ID07357 2022-01-19   East       Boston  Crackers     Whole Wheat  149
# 7  ID07358 2022-01-22   West  Los Angeles      Bars          Carrot   51
# 8  ID07359 2022-01-25   East     New York      Bars          Carrot  100
# 9  ID07360 2022-01-28   East     New York    Snacks    Potato Chips   28
#
#    UnitPrice  TotalPrice
# 0       1.77       58.41
# 1       3.49      303.63
# 2       1.87      108.46
# 3       1.87      153.34
# 4       2.18       82.84
# 5       1.77       95.58
# 6       3.49      520.01
# 7       1.77       90.27
# 8       1.77      177.00
# 9       1.35       37.80

# %%
pd.read_excel(xlsx_files[2], nrows=10)
# Out:
#         ID       Date Region         City  Category         Product  Qty  \
# 0  ID07351 2022-01-01   East       Boston      Bars          Carrot   33
# 1  ID07352 2022-01-04   East       Boston  Crackers     Whole Wheat   87
# 2  ID07353 2022-01-07   West  Los Angeles   Cookies  Chocolate Chip   58
# 3  ID07354 2022-01-10   East     New York   Cookies  Chocolate Chip   82
# 4  ID07355 2022-01-13   East       Boston   Cookies       Arrowroot   38
# 5  ID07356 2022-01-16   East       Boston      Bars          Carrot   54
# 6  ID07357 2022-01-19   East       Boston  Crackers     Whole Wheat  149
# 7  ID07358 2022-01-22   West  Los Angeles      Bars          Carrot   51
# 8  ID07359 2022-01-25   East     New York      Bars          Carrot  100
# 9  ID07360 2022-01-28   East     New York    Snacks    Potato Chips   28
#
#    UnitPrice  TotalPrice
# 0       1.77       58.41
# 1       3.49      303.63
# 2       1.87      108.46
# 3       1.87      153.34
# 4       2.18       82.84
# 5       1.77       95.58
# 6       3.49      520.01
# 7       1.77       90.27
# 8       1.77      177.00
# 9       1.35       37.80
