# %% [markdown]
# <a href="https://colab.research.google.com/github/Xaviera8/datasci_1_loading/blob/main/HHA507CLASS1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Assignement Instructions
# Week 1: Introduction to Jupyter Notebooks (Google Colab) and Data Acquisition
# Objective:
#
# Familiarize yourself with Jupyter Notebook (Google Colab), practice data acquisition techniques, and begin using GitHub for assignment submissions.
# Instructions:
# 1. Setting Up Google Colab:
#
#     Create a new notebook in Google Colab.
#     Familiarize yourself with the Colab interface: exploring the menu options, inserting code and text cells, and using the file browser.
#
# 2. Data Acquisition:
#
#     Find and download at least 2-3 different CSV datasets (less than 10MB each) that do not contain any PHI/PII.
#     Similarly, find and download 3 XLSX files and 3 JSON files with the same criteria.
#     Use pandas to load each of these datasets into separate data frames in your Colab notebook.
#     Display the first 10 rows of each dataset in separate code cells.
#
# 3. Markdown Practice:
#
#     Add a markdown cell and list the features (columns) of each dataset.
#     For each feature, give a brief description of its content/purpose.
#
# 3. Submission:
#
#     * Create a new GitHub repository named datasci_1_loading in your GitHub account.
#     * Organize your GitHub repository with the following:
#   Within your repository, create a folder named "data" to store your acquired datasets.
#     * Save your Colab notebook to your GitHub repository.
#     * Submit the link to your GitHub repository.

# %% [markdown]
# #Import Pandas

# %%
import pandas as pd

# %% [markdown]
# #Insert Files

# %%
csvs = ['nba_draft_combine_all_years.csv',
        'NBA Season Data.csv']

json_files = ['pokeapi.co.json',
              'rickandmortyapi.com.json',
              'SP.POP.TOTL.json']

xlsx_files = ['winter.xlsx',
              'sampledatafoodinfo.xlsx',
              'sampledatafoodsales.xlsx',
              'SampleData.xlsx',
              'winter.xlsx']

# %% [markdown]
# #Read CSVs
#
#
# ---
#
#
# ### CSV 1

# %%
csv1 = pd.read_csv(csvs[0], nrows=10)
csv1
# Out:
#    Unnamed: 0             Player  Year  Draft pick  Height (No Shoes)  \
# 0           0      Blake Griffin  2009           1              80.50
# 1           1  Terrence Williams  2009          11              77.00
# 2           2   Gerald Henderson  2009          12              76.00
# 3           3   Tyler Hansbrough  2009          13              80.25
# 4           4         Earl Clark  2009          14              80.50
# 5           5        Austin Daye  2009          15              81.75
# 6           6      James Johnson  2009          16              79.00
# 7           7       Jrue Holiday  2009          17              75.25
# 8           8          Ty Lawson  2009          18              71.25
# 9           9        Jeff Teague  2009          19              72.25
#
#    Height (With Shoes)  Wingspan  Standing reach  Vertical (Max)  \
# 0                82.00     83.25           105.0            35.5
# ...

# %% [markdown]
# * Player:
# this is the name of the player
# * Year:
# this is the year the player was drafted
# * Draft Pick:
# this is the position the player wasselected in their respective draft
# * Height No Shoes:
# the player's height without shoes
# * Height with shoes:
# the player's height with shoes
# * Wingspan
# this is a measurement of a player's measured arm length from fingertip to fingertip
# * Standing Reach: this is a measurement of how high a player can reach with their hands while standing flat-footed
#
#
#
# ---
#
#
# ### CSV 2

# %%
csv2 = pd.read_csv(csvs[1], nrows=10)
csv2
# Out:
#    Year   Tm          Player  Age   G    MP   PER    TS%  3PAr    FTr  ...  \
# 0  1978  NOJ  Truck Robinson   26  82  3638  15.7  0.481   NaN  0.340  ...
# 1  1978  BUF     Randy Smith   29  82  3314  19.1  0.521   NaN  0.326  ...
# 2  1978  WSB     Elvin Hayes   32  81  3246  17.1  0.489   NaN  0.365  ...
# 3  1978  BOS     Dave Cowens   29  77  3215  18.6  0.533   NaN  0.233  ...
# 4  1978  NYK      Bob McAdoo   26  79  3182  22.0  0.567   NaN  0.412  ...
# 5  1978  NJN    Bernard King   21  79  3092  17.3  0.511   NaN  0.277  ...
# 6  1978  CHI   Artis Gilmore   28  82  3067  23.5  0.604   NaN  0.531  ...
# 7  1978  DEN  David Thompson   23  80  3025  23.2  0.578   NaN  0.422  ...
# 8  1978  GSW      Rick Barry   33  82  3024  20.9  0.509   NaN  0.243  ...
# 9  1978  IND    Ricky Sobers   25  79  3019  15.4  0.514   NaN  0.328  ...
#
#    D-WORP  Adjusted WORP  Estimated Position  BBRef Pos  Age on Feb 1  \
# 0     1.1            1.1                 3.6          4         26.33
# ...

# %% [markdown]
#   *  Player: The name of the player
#   *   Age: The age of the player during the specified season
#   *  G: Number of games the player has participated in
#   *   MP: Minutes played by the player
#   *  PER: Player Efficiency Rating, a per-minute rating that summarizes a player's statistical accomplishments in a single number
#   *  TS%: True Shooting Percentage, a measure of shooting efficiency that takes into account field goals, 3-point field goals, and free throws
#   *  3PAr: 3-Point Attempt Rate, which is the portion of a player's shots that are three-point attempts
#   *  FTr: Free Throw Rate, which represents how often a player gets to  the free throw line relative to how often they shoot the ball

# %% [markdown]
# #Read XLSX files
#
#
# ---
#
#
# ### XLSX 1

# %%
xlsx = pd.read_excel(xlsx_files[0], nrows = 10)
xlsx
# Out:
#          Athletes Data 4 Athletes with 2 Sports       Athletes 2606  \
# 0                  NaN                      NaN            NaN  NaN
# 1                 Name                    Sport    Nationality  Age
# 2       ABBAS Muhammad            Alpine Skiing       Pakistan   23
# 3        ABBOTT Jeremy           Figure Skating  United States   24
# 4         ABLAEV Enver         Freestyle Skiing        Ukraine   30
# 5   ABRAMASHVILI Iason            Alpine Skiing        Georgia   21
# 6     ABRAMENKO Evgeny                 Biathlon        Belarus   22
# 7  ABRAMENKO Oleksandr         Freestyle Skiing        Ukraine   21
# 8  ABRAMOVA Yekaterina            Speed Skating         Russia   27
# 9   ABRAMOVITCH Dmitry                Bobsleigh         Russia   27
#
#   Unnamed: 4 Unnamed: 5
# 0        NaN        NaN
# 1      Wt kg         Ht
# 2         55        168
# 3        NaN        175
# 4         68        169
# 5         82        176
# 6         81        180
# ...

# %% [markdown]
#   * Name: The full name or identity of the athlete.
#   * Sport: The specific athletic activity or discipline the individual participates in.
#   * Nationality: The country or nation the athlete represents.
#   * Age: The age of the athlete.
#   * Wt kg: Weight of the athlete, measured in kilograms.
#   * Ht: Height of the athlete.

# %% [markdown]
# ---
#
#
# ### XLSX 2

# %%
xlsx2 = pd.read_excel(xlsx_files[1], nrows=10)
xlsx2
# Out:
#         ID       Date Region         City  Category         Product  Qty  \
# 0  ID07351 2022-01-01   East       Boston      Bars          Carrot   33
# 1  ID07352 2022-01-04   East       Boston  Crackers     Whole Wheat   87
# 2  ID07353 2022-01-07   West  Los Angeles   Cookies  Chocolate Chip   58
# 3  ID07354 2022-01-10   East     New York   Cookies  Chocolate Chip   82
# 4  ID07355 2022-01-13   East       Boston   Cookies       Arrowroot   38
# 5  ID07356 2022-01-16   East       Boston      Bars          Carrot   54
# 6  ID07357 2022-01-19   East       Boston  Crackers     Whole Wheat  149
# 7  ID07358 2022-01-22   West  Los Angeles      Bars          Carrot   51
# 8  ID07359 2022-01-25   East     New York      Bars          Carrot  100
# 9  ID07360 2022-01-28   East     New York    Snacks    Potato Chips   28
#
#    UnitPrice  TotalPrice
# 0       1.77       58.41
# 1       3.49      303.63
# 2       1.87      108.46
# 3       1.87      153.34
# 4       2.18       82.84
# ...

# %% [markdown]
#  * ID: An identification Number
#  * Date: The day when the transaction took place
#  * Region: The geographical area where the transaction occurred
#  * City: The city of the transaction
#  * Category: The group the product belongs to
#  * Product: The item or good being sold
#  * Qty: The quantity or number of products involved
#  * UnitPrice: The cost or price of one unit of the product
#  * TotalPrice: The complete cost for all units

# %% [markdown]
# ---
#
#
# ### XLSX 3

# %%
xlsx3 = pd.read_excel(xlsx_files[3], nrows=10)
xlsx3
# Out:
#    OrderDate   Region       Rep    Item  Units  Unit Cost   Total
# 0 2021-01-06     East     Jones  Pencil     95       1.99  189.05
# 1 2021-01-23  Central    Kivell  Binder     50      19.99  999.50
# 2 2021-02-09  Central   Jardine  Pencil     36       4.99  179.64
# 3 2021-02-26  Central      Gill     Pen     27      19.99  539.73
# 4 2021-03-15     West   Sorvino  Pencil     56       2.99  167.44
# 5 2021-04-01     East     Jones  Binder     60       4.99  299.40
# 6 2021-04-18  Central   Andrews  Pencil     75       1.99  149.25
# 7 2021-05-05  Central   Jardine  Pencil     90       4.99  449.10
# 8 2021-05-22     West  Thompson  Pencil     32       1.99   63.68
# 9 2021-06-08     East     Jones  Binder     60       8.99  539.40

# %% [markdown]
# * OrderDate: The date when the order was placed
# * Region: The  area where the order originates
# * Rep: The representative responsible for the order
# * Item: The product being ordered
# * Units: The quantity of items ordered
# * Unit Cost: The price of a single unit
# * Total: The overall cost for the entire order

# %% [markdown]
# #Read Json Files
#
#
# ---
#
#
# ## I have tried several JSON files but keep getting different issues I am not sure how to solve
#
#
# ---
#
#
# ### JSON 1

# %%
json1 = pd.read_json(json_files[0])
json1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-de51c68235eb> in <cell line: 1>()
# ----> 1 json1 = pd.read_json(json_files[0])
#       2 json1
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %% [markdown]
# ---
#
#
# ### JSON 2

# %%
json2 = pd.read_json(json_files[1])
json2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-237f5add6a6e> in <cell line: 1>()
# ----> 1 json2 = pd.read_json(json_files[1])
#       2 json2
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %% [markdown]
# ---
#
#
# ### JSON 3

# %%
json3 = pd.read_json(json_files[2])
json3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-7f68d62eb37e> in <cell line: 1>()
# ----> 1 json3 = pd.read_json(json_files[2])
#       2 json3
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...
